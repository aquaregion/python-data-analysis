# %% [markdown]
# # matplotlib
# <img src="http://matplotlib.org/1.4.3/_static/logo2.png" width=400></img>
#
#
#
# *some of the examples here were taken from the excelent lecture series by J.R. Johansson (robert@riken.jp)  http://dml.riken.jp/~rob/.
#
# The other notebooks in this lecture series are indexed at [http://jrjohansson.github.com](http://jrjohansson.github.com).

# %% [markdown]
# # Introduction
#
# Matplotlib is an excellent 2D and 3D graphics library for generating scientific figures. Some of the many advantages of this library includs:
#
# * Easy to get started
# * Support for $\LaTeX$-formatted labels and texts
# * Great control of every element in a figure, including figure size and DPI.
# * High-quality output in many formats, including PNG, PDF, SVG, EPS.
# * GUI for interactively exploring figures *and* support for headless generation of figure files (useful for batch jobs).

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.xkcd()

# %%
x = np.linspace(0, 5, 10)
y = x ** 2

# %% [markdown]
# Now we make the figure:

# %%
plt.plot(x, y, marker='o',color='b',alpha=0.5)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Nice title')

# %% [markdown]
# The syntax is similar to the one of Matlab

# %%
plt.subplot(2,2,1)
plt.plot(x, y, 'r--')
plt.subplot(2,2,2)
plt.plot(y, x, 'g*-')
plt.subplot(2,2,3)
plt.plot(x, y, 'r--')
plt.subplot(2,2,4)
plt.plot(y, x, 'g*-');

# %% [markdown]
# But it can become even more similar.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x1 = linspace(-2*pi,2*pi);
y1 = sin(x1);
y2 = cos(x1);
plot(x1,y1,x1,y2)

# %% [markdown]
# # The matplotlib object-oriented API

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(1,2,1) #one row, two columns, first plot
ax.plot(x1,y1,x1,y2,label=["f1","f2"])
ax.set_xlabel("X")
ax.set_ylabel("y")
ax.legend()
ax2 = fig.add_subplot(1,2,2) #one row, two columns, second plot
ax2.plot(x1,y1**2,x1,y2**2)

# %%
# %matplotlib inline
fig = plt.figure()

ax = fig.add_subplot(2,1,1) #two rows, one column, first plot
ax.plot(x1,y1,x1,y2)


ax2 = fig.add_subplot(2,1,2) #two rows, one column, second plot
ax2.plot(x1,y1**2,x1,y2**2)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# main figure
ax.plot(x, y, 'r')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
ax2  = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes
# # inset
ax2.plot(y, x, 'g')
ax2.set_ylabel('y')
ax2.set_xlabel('x')
ax2.set_title('inset title');

# %%
fig, axes = plt.subplots()

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

for ax in axes.flatten():
    ax.plot(x, y, 'r')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title');

# %%
axes
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x116043310>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x1160a7d10>]], dtype=object)

# %%
# %config InlineBackend.figure_format = "png"

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x, y, 'r')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')
    
fig.tight_layout()

# %% [markdown]
# ## Figure size, aspect ratio and DPI

# %%
fig = plt.figure(figsize=(8,4), dpi=100)

# %% [markdown]
# The same arguments can also be passed to layout managers, such as the `subplots` function.

# %%
fig, axes = plt.subplots(figsize=(5,5))

axes.plot(x, y, 'ro')
axes.plot(y, x, 'g--')
axes.plot(y, y, 'bd')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %% [markdown]
# ## Saving figures
#
# To save a figure a file we can use the `savefig` method in the `Figure` class.

# %%
fig.savefig("filename.png")

# %%
fig.savefig("filename.png", dpi=600)

# %%
fig.savefig("filename.svg")

# %% [markdown]
# ## Legends, labels and titles

# %% [markdown]
# **Figure titles**
#
# A title can be added to each axis instance in a figure. To set the title use the `set_title` method in the axes instance:

# %%
ax.set_title("title")

# %% [markdown]
# **Axis labels**
#
# Similarly, using the methods `set_xlabel` and `set_ylabel` we can set the labels of the X and Y axes:

# %%
ax.set_xlabel("x")
ax.set_ylabel("y")

# %% [markdown]
# **Legends**
#
# Legends to curves in a figure can be added in two ways. First method is to use the `legend` method of the axis object and pass a list/tuple of legend texts for the curves that have previously been added:

# %%
ax.legend(["curve1", "curve2", "curve3"]);

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(x, x**2, label="curve1")
ax.plot(x, x**3, label="curve2")
ax.legend(loc='best',fontsize=20);

# %%
ax.legend(loc=0) # let matplotlib decide the optimal location
ax.legend(loc=1) # upper right corner
ax.legend(loc=2) # upper left corner
ax.legend(loc=3) # lower left corner
ax.legend(loc=4) # lower right corner
# .. many more options are available

# %%
fig, ax = subplots()

ax.plot(x, x**2, label="y = x**2")
ax.plot(x, x**3, label="y = x**3")
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')
ax.legend(loc=2); # upper left corner

# %% [markdown]
# ## Formatting text: LaTeX, fontsize, font family

# %%
fig, ax = subplots()

ax.plot(x, x**2, label=r"$y = \alpha^2$")
ax.plot(x, x**3, label=r"$y = \alpha^3$")
ax.set_xlabel(r'$\alpha$', fontsize=18)
ax.set_ylabel(r'$y$', fontsize=18)
ax.set_title('title')
ax.legend(loc=2); # upper left corner

# %%
# Update the matplotlib configuration parameters:
matplotlib.rcParams.update({'font.size': 18, 'font.family': 'serif'})

# %%
fig, ax = subplots()

ax.plot(x, x**2, label=r"$y = \alpha^2$")
ax.plot(x, x**3, label=r"$y = \alpha^3$")
ax.set_xlabel(r'$\alpha$')
ax.set_ylabel(r'$y$')
ax.set_title('title')
ax.legend(loc=2); # upper left corner

# %%
# restore
matplotlib.rcParams.update({'font.size': 12, 'font.family': 'sans'})

# %% [markdown]
# ## Setting colors, linewidths, linetypes
#
# ### Colors

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
# MATLAB style line color and style 
ax.plot(x, x**2, 'b.-') # blue line with dots
ax.plot(x, x**3, 'g--') # green dashed line

# %% [markdown]
# In matplotlib we can also define colors by their name or RGB hex codes, and optionally provide an alpha value, using the `color` and `alpha` keyword arguments:

# %%
fig, ax = subplots()

ax.plot(x, x+1, color="red", alpha=0.5) # half-transparant red
ax.plot(x, x+2, color="#1155dd")        # RGB hex code for a bluish color
ax.plot(x, x+3, color="#15cc55")        # RGB hex code for a greenish color

# %% [markdown]
# ### Line and marker styles
#
# To change the line width we can use the `linewidth` or `lw` keyword argument, and the line style can be selected using the `linestyle` or `ls` keyword arguments:

# %%
fig, ax = subplots(figsize=(12,6))

ax.plot(x, x+1, color="blue", linewidth=0.25)
ax.plot(x, x+2, color="blue", linewidth=0.50)
ax.plot(x, x+3, color="blue", linewidth=1.00)
ax.plot(x, x+4, color="blue", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="red", lw=2, linestyle='-')
ax.plot(x, x+6, color="red", lw=2, ls='-.')
ax.plot(x, x+7, color="red", lw=2, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="green", lw=1, ls='*', marker='+')
ax.plot(x, x+10, color="green", lw=1, ls='*', marker='o')
ax.plot(x, x+11, color="green", lw=1, ls='*', marker='s')
ax.plot(x, x+12, color="green", lw=1, ls='*', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=2, markeredgecolor="blue");

# %% [markdown]
# ## Control over axis apperance
#
# The appearance of the axes is an important aspect of a figure that we often need to modify to make a publication quality graphics. We need to be able to control where the ticks and labels are placed, modify the font size and possibly the labels used on the axes. In this section we will look at controling those properties in a matplotlib figure.
#
# ### Plot range
#
# The first thing we might want to configure is the ranges of the axes. We can do it using the `set_ylim` and `set_xlim` methods in the axis object, or `axis('tight')` for automatrically getting "tightly fitted" axes ranges.

# %%
fig, axes = subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");

# %%
fig, axes = subplots(1, 4, figsize=(16, 4))
axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("linear axes")
axes[0].set_yscale('log')

axes[1].plot(x, x**2, x, x**3)
axes[1].set_title("Semilog x axes")
axes[1].set_xscale('log')

axes[2].plot(x, x**2, x, x**3)
axes[2].set_title("Semilog y axes")
axes[2].set_yscale('log')

axes[3].plot(x, x**2, x, x**3)
axes[3].set_title("Log-log axes")
axes[3].set_yscale('log')
axes[3].set_xscale('log')

# %%
fig, axes = subplots(1, 4, figsize=(16, 4))
axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("linear axes")

axes[1].semilogx(x, x**2, x, x**3)
axes[1].set_title("Semilog x axes")

axes[2].semilogy(x, x**2, x, x**3)
axes[2].set_title("Semilog y axes")

axes[3].loglog(x, x**2, x, x**3)
axes[3].set_title("Log-log axes")

# %% [markdown]
# ## Text annotation
#
# Annotating text in matplotlib figures can be done using the `text` function. It supports LaTeX formatting just like axis label texts and titles:

# %%
fig, ax = subplots()

ax.plot(x, x**2, x, x**3)

ax.text(2, 60, r"$y=x^2$", fontsize=20, color="blue")
ax.text(2,80, r"$y=x^3$", fontsize=20, color="green");
